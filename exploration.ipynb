# %%
from fileopener import import_file_from_web, import_data_on_python, import_data_excel_to_pandas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import csv

# %%
url1csv = "https://www.data.gouv.fr/fr/datasets/r/6fadff46-9efd-4c53-942a-54aca783c30c"
url2csv = "https://www.data.gouv.fr/fr/datasets/r/eceb9fb4-3ebc-4da3-828d-f5939712600a"
url3csv = "https://www.data.gouv.fr/fr/datasets/r/426bab53-e3f5-4c6a-9d54-dba4442b3dbc"
url1xlsx = "https://data.drees.solidarites-sante.gouv.fr/api/datasets/1.0/601_indicateurs-de-contexte/attachments/c04_isd_esperance_de_vie_xlsx/"
url2xlsx = "https://data.drees.solidarites-sante.gouv.fr/api/datasets/1.0/601_indicateurs-de-contexte/attachments/c03_isd_taux_de_mortalite_xlsx/"
url3xlsx = "https://data.drees.solidarites-sante.gouv.fr/api/datasets/1.0/601_indicateurs-de-contexte/attachments/c10_isd_disparite_des_niveaux_de_vie_xlsx/"
url4xlsx = "https://data.drees.solidarites-sante.gouv.fr/api/datasets/1.0/601_indicateurs-de-contexte/attachments/c08_isd_intensite_de_la_pauvrete_monetaire_xlsx/"
url5xlsx = "https://data.drees.solidarites-sante.gouv.fr/api/datasets/1.0/601_indicateurs-de-contexte/attachments/c02_isd_indice_de_vieillissement_xlsx/"
url6xlsx = "https://data.drees.solidarites-sante.gouv.fr/api/datasets/1.0/601_indicateurs-de-contexte/attachments/c01_isd_population_selon_age_xlsx/"
url7xlsx = "https://www.data.gouv.fr/fr/datasets/r/98f3161f-79ff-4f16-8f6a-6d571a80fea2"

# %%
df1 = pd.read_csv(url1csv, sep=";", encoding="latin1")
print(
    df1.sample(5),
    df1.size
)
# Out:
#        dep        jour  incid_hosp  incid_rea  incid_dc  incid_rad
# 49143   44  2021-04-14          33          4         5         43
# 2393    03  2020-09-12           0          0         0          0
# 104297  94  2020-08-11          12          2         0          7
# 61773   55  2022-06-30           0          0         0          0
# 104600  94  2021-06-10           5          2         1         26 678096

# %%
"""lire ce document pour pouvoir l'utiliser et le merge aux autres"""
df6xlsx = pd.read_excel(url6xlsx, skiprows=4, header=[0,1])

# %%
df6xlsx.head(5)
# Out:
#         Départements                          Population par âge (en nombre)  \
#   Unnamed: 0_level_1       Unnamed: 1_level_1                Moins de 20 ans
# 0                 01                      Ain                       171336.0
# 1                 02                    Aisne                       125708.0
# 2                 03                   Allier                        66246.0
# 3                 04  Alpes-de-Haute-Provence                        33920.0
# 4                 05             Hautes-Alpes                        27874.0
#
#                                                                             \
#   Moins de 25 ans 25 à 64 ans 65 ans ou plus 75 ans ou plus 80 ans ou plus
# 0        203449.0    344459.0       131590.0        61926.0        35163.0
# 1        152860.0    251931.0       116841.0        53128.0        29580.0
# 2         81986.0    152745.0        97977.0        49747.0        29925.0
# 3         40903.0     80162.0        47096.0        23412.0        13630.0
# 4         33506.0     68377.0        39778.0        19651.0        11323.0
#
#                   Population totale Population par âge (en %)                  \
#   85 ans ou plus Unnamed: 9_level_1           Moins de 20 ans Moins de 25 ans
# 0        18688.0           679498.0                 25.215085       29.941074
# 1        16774.0           521632.0                 24.098982       29.304184
# 2        17424.0           332708.0                 19.911153       24.642028
# 3         7259.0           168161.0                 20.171146       24.323714
# 4         6406.0           141661.0                 19.676552       23.652240
#
#                                                                            \
#   25 à 64 ans 65 ans ou plus 75 ans ou plus 80 ans ou plus 85 ans ou plus
# 0   50.693159      19.365767       9.113493       5.174850       2.750266
# 1   48.296692      22.399124      10.184958       5.670664       3.215677
# 2   45.909626      29.448345      14.952150       8.994373       5.237025
# 3   47.669793      28.006494      13.922372       8.105328       4.316696
# 4   48.268048      28.079711      13.871849       7.993026       4.522063
#
#
#   85 ans ou plus.1
# 0                1
# 1                2
# 2                3
# 3                4
# 4                5
