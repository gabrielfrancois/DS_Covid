# %%
from datapreprocessing import df_final

# %%
df_final.head(20)
# Out:
#                          nom_dep  Moins de 20 ans  Moins de 25 ans  \
# num_dep
# 01                           Ain         171336.0         203449.0
# 02                         Aisne         125708.0         152860.0
# 03                        Allier          66246.0          81986.0
# 04       Alpes-de-Haute-Provence          33920.0          40903.0
# 05                  Hautes-Alpes          27874.0          33506.0
# 06               Alpes-Maritimes         232394.0         289883.0
# 07                       Ardèche          71110.0          85351.0
# 08                      Ardennes          59918.0          72667.0
# 09                        Ariège          31329.0          38135.0
# 10                          Aube          75012.0          93036.0
# 11                          Aude          78118.0          95026.0
# 12                       Aveyron          54611.0          66330.0
# 13              Bouches-du-Rhône         471361.0         593502.0
# ...

# %%
df_final.columns.to_list()
# Out:
# ['nom_dep',
#  'Moins de 20 ans',
#  'Moins de 25 ans',
#  '25 à 64 ans',
#  '65 ans ou plus',
#  '75 ans ou plus',
#  '80 ans ou plus',
#  '85 ans ou plus',
#  'pop_totale',
#  'Moins de 20 ans.1',
#  'Moins de 25 ans.1',
#  '25 à 64 ans.1',
#  '65 ans ou plus.1',
#  '75 ans ou plus.1',
#  '80 ans ou plus.1',
#  '85 ans ou plus.1',
#  'nb hospitalisations',
#  'nb deces',
#  'espérance de vie',
#  'passage_urg_corona',
#  'nb_etab_sante',
#  'esp_de_vie_H_60',
#  'esp_de_vie_F_60',
#  'esp_de_vie_H_65',
#  'esp_de_vie_F_65',
#  'rapport nv_vie interdécile D9/D1',
#  'indicateur pauvreté 1',
#  'indicateur pauvreté 2']

# %%
df_final_test = df_final.copy()
df_final_test[]
